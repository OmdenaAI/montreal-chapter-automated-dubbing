# %% [markdown]
# ## Dubbing App - pipeline testing
#
# Tests the execution of the pipeline, calling the multiple functions, step-by-step

# %%
from IPython.display import Audio, Video

from dubbing_app.dubbing_app import DubbingApp
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# Parameters

# %%
# video_url = "https://www.youtube.com/watch?v=5q4KXshCcP0&ab_channel=LingoMasterySpanish"
video_url = "https://www.youtube.com/watch?v=-94nhNBw51I"
# video_url = "https://www.youtube.com/watch?v=MUQTpYBBVbA&ab_channel=FernandoMart%C3%ADnezdeCarneroCalzada"
# video_url  = "https://youtu.be/VfStQ5GWQm0"

#video_url  = "https://www.youtube.com/watch?v=FCkfytrmV1s"

target_language = "en"

# %%
# create the main object 
app = DubbingApp()

# %% [markdown]
# ### 1. Video Processing

# %%
video_file_path = video_file_path = app.video_processor.get_video(video_url)

print(f"\"{video_file_path}\"")
# Out:
# "media/¡Lanzamos TED en Español!.mp4"

# %%
Video(video_file_path, width=640, height=360)
# Out:
# <video src="media/¡Lanzamos TED en Español!.mp4" controls  width="640"  height="360">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
audio_file_path = app.video_processor.extract_audio(video_file_path)

print(f"\"{audio_file_path}\"")
# Out:
# "media/¡Lanzamos TED en Español!.mp3"

# %%
Audio(audio_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 2. Speech-to-Text

# %%
# Perform speech-to-text conversion on the audio
timestamped_text = app.speech2text_processor.speech_to_text(audio_file_path)
# Out:
# INFO     Device used: cpu
# INFO     ############################################################################################################
# INFO     Model is multilingual
# INFO     Detected language: es
# WARNING  /Users/ricardo/anaconda3/envs/dub/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
# Gender detection not working, don't run this
#app.speech2text_processor.get_speakers_gender(audio_file_path)

# %%
timestamped_text
# Out:
# {'segments': [{'id': 0,
#    'start': 0.0,
#    'end': 10.84,
#    'speaker_gender': '',
#    'text': ' En un mundo que parecería estar dividiendo sea decidimos tomar medidas. Vamos a lanzar Ted en español.',
#    'audio': None},
#   {'id': 1,
#    'start': 10.84,
#    'end': 16.48,
#    'speaker_gender': '',
#    'text': ' Por primera vez en la historia de Ted vamos a tener un bloque entero de charlas en otro idioma.',
#    'audio': None},
#   {'id': 2,
#    'start': 16.48,
#    'end': 23.68,
#    'speaker_gender': '',
#    'text': ' Para celebrar este momento histórico decidimos que vamos a compartir con todo el mundo en vivo y en directo Ted en español,',
#    'audio': None},
#   {'id': 3,
#    'start': 23.68,
#    'end': 26.52,
#    'speaker_gender': '',
#    'text': ' el 25 de abril desde Vancouver.',
#    'audio': None},
#   {'id': 4,
#    'start': 26.52,
#    'end': 37.68,
#    'speaker_gender': '',
#    'text': ' En Ted en español tendremos seis oradores de lujo. Uno de ellos es Ingrid de Tancourt, que como Sabran estuvo secuestrada por las FARC en Colombia durante más de seis años.',
#    'audio': None},
#   {'id': 5,
#    'start': 37.68,
#    'end': 41.2,
#    'speaker_gender': '',
#    'text': ' En su charla va a compartir que aprendió durante todo ese tiempo.',
#    'audio': None},
#   {'id': 6,
#    'start': 41.2,
#    'end': 46.68,
#    'speaker_gender': '',
#    'text': ' Jorge Ramos en su charla va a compartir con todos, que significa para él ser inmigrante.',
#    'audio': None},
#   {'id': 7,
#    'start': 46.68,
#    'end': 52.760000000000005,
#    'speaker_gender': '',
#    'text': ' Jorge Drexler, el músico y poeta va a compartir con todos la historia de una canción.',
#    'audio': None},
#   {'id': 8,
#    'start': 52.8,
#    'end': 58.519999999999996,
#    'speaker_gender': '',
#    'text': ' Lo más araceno es un artista increíble que desafía los límites de lo que creemos que es posible.',
#    'audio': None},
#   {'id': 9,
#    'start': 58.519999999999996,
#    'end': 65.24,
#    'speaker_gender': '',
#    'text': ' Gabriel Agonzales fue protagonista y lideró uno de los grandes descubrimientos científicos de los últimos tiempos.',
#    'audio': None},
#   {'id': 10,
#    'start': 65.24,
#    'end': 70.88,
#    'speaker_gender': '',
#    'text': ' Y Saber Venke estudia el origen de la fiesta en las culturas humanas.',
#    'audio': None},
#   {'id': 11,
#    'start': 70.88,
#    'end': 72.16,
#    'speaker_gender': '',
#    'text': ' Y no tan humadas.',
#    'audio': None},
#   {'id': 12,
#    'start': 72.16,
#    'end': 79.16,
#    'speaker_gender': '',
#    'text': ' Entonces el 25 de abril esperamos que nos acompañen en este gran hito que es el lanzamiento de Ted en español.',
#    'audio': None}],
#  'original_language': 'es',
#  'original_text': ' En un mundo que parecería estar dividiendo sea decidimos tomar medidas. Vamos a lanzar Ted en español. Por primera vez en la historia de Ted vamos a tener un bloque entero de charlas en otro idioma. Para celebrar este momento histórico decidimos que vamos a compartir con todo el mundo en vivo y en directo Ted en español, el 25 de abril desde Vancouver. En Ted en español tendremos seis oradores de lujo. Uno de ellos es Ingrid de Tancourt, que como Sabran estuvo secuestrada por las FARC en Colombia durante más de seis años. En su charla va a compartir que aprendió durante todo ese tiempo. Jorge Ramos en su charla va a compartir con todos, que significa para él ser inmigrante. Jorge Drexler, el músico y poeta va a compartir con todos la historia de una canción. Lo más araceno es un artista increíble que desafía los límites de lo que creemos que es posible. Gabriel Agonzales fue protagonista y lideró uno de los grandes descubrimientos científicos de los últimos tiempos. Y Saber Venke estudia el origen de la fiesta en las culturas humanas. Y no tan humadas. Entonces el 25 de abril esperamos que nos acompañen en este gran hito que es el lanzamiento de Ted en español.'}

# %% [markdown]
# ### 3. Text Translation

# %%
# Translate the text to the selected target language
translated_text = app.text_processor.translate_text_segments(timestamped_text, target_language)

# %%
translated_text
# Out:
# {'segments': [{'id': 0,
#    'start': 0.0,
#    'end': 10.84,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 56 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 1,
#    'start': 10.84,
#    'end': 16.48,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 56 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 2,
#    'start': 16.48,
#    'end': 23.68,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 3,
#    'start': 23.68,
#    'end': 26.52,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 4,
#    'start': 26.52,
#    'end': 37.68,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 5,
#    'start': 37.68,
#    'end': 41.2,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 6,
#    'start': 41.2,
#    'end': 46.68,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 7,
#    'start': 46.68,
#    'end': 52.760000000000005,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 8,
#    'start': 52.8,
#    'end': 58.519999999999996,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 9,
#    'start': 58.519999999999996,
#    'end': 65.24,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 10,
#    'start': 65.24,
#    'end': 70.88,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 53 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 11,
#    'start': 70.88,
#    'end': 72.16,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 53 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None},
#   {'id': 12,
#    'start': 72.16,
#    'end': 79.16,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 53 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': None}],
#  'original_language': 'es',
#  'original_text': ' En un mundo que parecería estar dividiendo sea decidimos tomar medidas. Vamos a lanzar Ted en español. Por primera vez en la historia de Ted vamos a tener un bloque entero de charlas en otro idioma. Para celebrar este momento histórico decidimos que vamos a compartir con todo el mundo en vivo y en directo Ted en español, el 25 de abril desde Vancouver. En Ted en español tendremos seis oradores de lujo. Uno de ellos es Ingrid de Tancourt, que como Sabran estuvo secuestrada por las FARC en Colombia durante más de seis años. En su charla va a compartir que aprendió durante todo ese tiempo. Jorge Ramos en su charla va a compartir con todos, que significa para él ser inmigrante. Jorge Drexler, el músico y poeta va a compartir con todos la historia de una canción. Lo más araceno es un artista increíble que desafía los límites de lo que creemos que es posible. Gabriel Agonzales fue protagonista y lideró uno de los grandes descubrimientos científicos de los últimos tiempos. Y Saber Venke estudia el origen de la fiesta en las culturas humanas. Y no tan humadas. Entonces el 25 de abril esperamos que nos acompañen en este gran hito que es el lanzamiento de Ted en español.'}

# %% [markdown]
# ### 4. Text-to-Speech

# %%
# Convert the translated text into speech
translated_audio = await app.text2speech_processor.text_to_speech(translated_text, target_language)

# %%
translated_audio
# Out:
# {'segments': [{'id': 0,
#    'start': 0.0,
#    'end': 10.84,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 56 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd884c0040>},
#   {'id': 1,
#    'start': 10.84,
#    'end': 16.48,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 56 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd884c2e00>},
#   {'id': 2,
#    'start': 16.48,
#    'end': 23.68,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd884c2f20>},
#   {'id': 3,
#    'start': 23.68,
#    'end': 26.52,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd884c39d0>},
#   {'id': 4,
#    'start': 26.52,
#    'end': 37.68,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd884c32b0>},
#   {'id': 5,
#    'start': 37.68,
#    'end': 41.2,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 55 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd9ddd0f70>},
#   {'id': 6,
#    'start': 41.2,
#    'end': 46.68,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd9ddd0b80>},
#   {'id': 7,
#    'start': 46.68,
#    'end': 52.760000000000005,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd78cc69e0>},
#   {'id': 8,
#    'start': 52.8,
#    'end': 58.519999999999996,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd9ddd2c50>},
#   {'id': 9,
#    'start': 58.519999999999996,
#    'end': 65.24,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 54 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd896fadd0>},
#   {'id': 10,
#    'start': 65.24,
#    'end': 70.88,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 53 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd896fb1c0>},
#   {'id': 11,
#    'start': 70.88,
#    'end': 72.16,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 53 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd896fb5e0>},
#   {'id': 12,
#    'start': 72.16,
#    'end': 79.16,
#    'speaker_gender': '',
#    'text': 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  20 HOURS 03 MINUTES 53 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE',
#    'audio': <pydub.audio_segment.AudioSegment at 0x7fdd896fb9d0>}],
#  'original_language': 'es',
#  'original_text': ' En un mundo que parecería estar dividiendo sea decidimos tomar medidas. Vamos a lanzar Ted en español. Por primera vez en la historia de Ted vamos a tener un bloque entero de charlas en otro idioma. Para celebrar este momento histórico decidimos que vamos a compartir con todo el mundo en vivo y en directo Ted en español, el 25 de abril desde Vancouver. En Ted en español tendremos seis oradores de lujo. Uno de ellos es Ingrid de Tancourt, que como Sabran estuvo secuestrada por las FARC en Colombia durante más de seis años. En su charla va a compartir que aprendió durante todo ese tiempo. Jorge Ramos en su charla va a compartir con todos, que significa para él ser inmigrante. Jorge Drexler, el músico y poeta va a compartir con todos la historia de una canción. Lo más araceno es un artista increíble que desafía los límites de lo que creemos que es posible. Gabriel Agonzales fue protagonista y lideró uno de los grandes descubrimientos científicos de los últimos tiempos. Y Saber Venke estudia el origen de la fiesta en las culturas humanas. Y no tan humadas. Entonces el 25 de abril esperamos que nos acompañen en este gran hito que es el lanzamiento de Ted en español.'}

# %% [markdown]
# ### 5. Dubbing

# %%
dubbed_audio = app.dubbing_processor.join_audio_segments(translated_audio)

# %%
dubbed_audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
dubbed_video_file_path = app.dubbing_processor.add_audio_to_video(video_file_path, dubbed_audio)
# Out:
# Moviepy - Building video media/¡Lanzamos TED en Español!_dubbed.mp4.
# MoviePy - Writing audio in ¡Lanzamos TED en Español!_dubbedTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video media/¡Lanzamos TED en Español!_dubbed.mp4
# t:  99%|██████████████████████████████████████████████████████████████████▌| 2133/2148 [00:24<00:00, 205.80it/s, now=None]WARNING  /Users/ricardo/anaconda3/envs/dub/lib/python3.10/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file media/¡Lanzamos TED en Español!.mp4, 2764800 bytes wanted but 0 bytes read,at frame 2147/2148, at time 89.55/89.56 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready media/¡Lanzamos TED en Español!_dubbed.mp4

# %%
dubbed_video_file_path
# Out:
# 'media/¡Lanzamos TED en Español!_dubbed.mp4'

# %%
Video(dubbed_video_file_path, width=640, height=360)
# Out:
# <video src="media/¡Lanzamos TED en Español!_dubbed.mp4" controls  width="640"  height="360">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### 0. Full Pipeline

# %%
new_video_url = await DubbingApp().process_pipeline(video_url, target_language)
# Out:
# INFO     Device used: cpu
# INFO     Device used: cpu
# INFO     ############################################################################################################
# INFO     ############################################################################################################
# INFO     Model is multilingual
# INFO     Model is multilingual
# INFO     Detected language: es
# INFO     Detected language: es
# WARNING  /Users/ricardo/anaconda3/envs/dub/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#
# WARNING  /Users/ricardo/anaconda3/envs/dub/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Moviepy - Building video media/¡Lanzamos TED en Español!_dubbed.mp4.
# MoviePy - Writing audio in ¡Lanzamos TED en Español!_dubbedTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video media/¡Lanzamos TED en Español!_dubbed.mp4
# t: 100%|███████████████████████████████████████████████████████████████████| 2148/2148 [00:26<00:00, 196.77it/s, now=None]WARNING  /Users/ricardo/anaconda3/envs/dub/lib/python3.10/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file media/¡Lanzamos TED en Español!.mp4, 2764800 bytes wanted but 0 bytes read,at frame 2147/2148, at time 89.55/89.56 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING  /Users/ricardo/anaconda3/envs/dub/lib/python3.10/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file media/¡Lanzamos TED en Español!.mp4, 2764800 bytes wanted but 0 bytes read,at frame 2147/2148, at time 89.55/89.56 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready media/¡Lanzamos TED en Español!_dubbed.mp4

# %%
new_video_url
# Out:
# 'media/¡Lanzamos TED en Español!_dubbed.mp4'
